# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Objective:
# Group patients into clusters of **Hight risk of Heart attack, Medium risk and Low risk** based on similarities in their health attributes (like blood pressure, cholesterol, age, etc.) without using any labels (i.e., unsupervised learning).

# %% [markdown]
# # Getting Familiar with the data:

# %%
df = pd.read_csv("heart_disease.csv")
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      0   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      1   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      2   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      3   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      4   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  915   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  916   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  917   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  918   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  919   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 107.9+ KB

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   459.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      0.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    229.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    459.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    689.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    919.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca
# count  309.000000
# mean     0.676375
# std      0.935653
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# # Preprocessing The Data:

# %%
df.drop(columns=['id'], inplace=True)

# %%
df['trestbps'] = df['trestbps'].fillna(df['trestbps'].median())
df['chol'] = df['chol'].fillna(df['chol'].median())
df['thalch'] = df['thalch'].fillna(df['thalch'].median())
df['oldpeak'] = df['oldpeak'].fillna(df['oldpeak'].median())
df['ca'] = df['ca'].fillna(df['ca'].median())

# %%
for col in ['fbs', 'restecg', 'exang', 'slope', 'thal']:
    df[col] = df[col].fillna(df[col].mode()[0])
# Out:
# C:\Users\HASHIR\AppData\Local\Temp\ipykernel_20936\61125900.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    int64
#  1   sex       920 non-null    object
#  2   dataset   920 non-null    object
#  3   cp        920 non-null    object
#  4   trestbps  920 non-null    float64
#  5   chol      920 non-null    float64
#  6   fbs       920 non-null    bool
#  7   restecg   920 non-null    object
#  8   thalch    920 non-null    float64
#  9   exang     920 non-null    bool
#  10  oldpeak   920 non-null    float64
#  11  slope     920 non-null    object
#  12  ca        920 non-null    float64
#  13  thal      920 non-null    object
# dtypes: bool(2), float64(5), int64(1), object(6)
# memory usage: 88.2+ KB

# %% [markdown]
# # Exploratory Data Analysis:

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['age'], kde=True, bins=30, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# The age column forms a kind of **Gaussian Distribution** with a lot of records in between 50 and 60. It also has a significant records in between 40-50.

# %%
numerical_cols = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca']
plt.figure(figsize=(15,10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data=df, y=col, color='lightgreen')
    plt.title(f'{col} Distribution')
    plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Box plot analysis:
# 1. **age Distribution** has majority of records in between **47-60**.
# 2. **testbps** has majority of records in between **120-140** with some outliers till 200.
# 3. **chol Distribution** has majority of records in between **180-270** with some outliers from 400-600.
# 4. **talch Distribution** has majority of records in between **120-155**.
# 5. **oldpeak Distribution** has majority of records in between **0-1.5** with some outliers till 6.
# 6. **ca Distribution** is almost 50% **0** and equally distributed for 3 outliers of 1 2 and 3.

# %%
categorical_cols = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal', 'dataset']
plt.figure(figsize=(18,12))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(3, 3, i)
    sns.countplot(data=df, x=col, hue=col, palette='Set2', legend=False,
                  order=df[col].value_counts().index)
    plt.title(f'Count of {col}')
    plt.xticks(rotation=45)
    plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Categorical columns analysis:
# 1. The Sex columns as almost **75%** *males* and **25%** *females*.
# 2. Cp column contains **60%** *asymptomatic*, **22%** *non anginal*, **20%** *atypical angina* and **7-8%** *typical angina records*.
# 3. fbs is **False** for **85%** of the records.
# 4. restecg contains **60%** *normal*, **20%** *Iv hypertrophy* and **20%** *st-t abnormality*.
# 5. exang is **False** for **65%** of the records.
# 6. slope is *flat* for **70%** of the records, *Upsloping* for **25%** and *downsloping* for the remaining **5%**
# 7. thal is *normal* for almost **73%** of the records, *reversable* defect for **23%** and *fixed defect* for remaining **4%**.
# 8. dataset columns contains **32%** records from *Cleaveland*, **32%** from *Hungary*, **21%** from *VA Long Beach* and the remaining from *Switzerland*.

# %%
sns.pairplot(df[['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca']], diag_kind='kde')
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()

# %% [markdown]
# # PairPlot Analysis:
# 1. **Age** is almost equally dirtributed for all the records. ca is **0** for age under 40.
# 2. **testbps** is between **100-200** for all the records.
# 3. **chol** is also equally distributed for all the features with large amount of data between **200-400**.
# 4. **thalch** is almost uniformly distributed for all the features.
# 5. **oldpeak** is >0 for almost all the features.
# 6. **ca** is also uniformly distributed for all the features.

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Correlation analysis:
# 1. Most of the corrilations are very low.
# 2. The heighest +ve correlation is **0.40** which is between **oldpeak and exang**.
# 3. The heighest -ve correlation is **-0.35** which is between **exang and thalch**.

# %% [markdown]
# # Dropping Unnecessary columns:

# %%
df.drop(columns=['dataset'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    int64
#  1   sex       920 non-null    object
#  2   cp        920 non-null    object
#  3   trestbps  920 non-null    float64
#  4   chol      920 non-null    float64
#  5   fbs       920 non-null    bool
#  6   restecg   920 non-null    object
#  7   thalch    920 non-null    float64
#  8   exang     920 non-null    bool
#  9   oldpeak   920 non-null    float64
#  10  slope     920 non-null    object
#  11  ca        920 non-null    float64
#  12  thal      920 non-null    object
# dtypes: bool(2), float64(5), int64(1), object(5)
# memory usage: 81.0+ KB

# %% [markdown]
# # One Hot Encoding Categorical Features:

# %%
categorical_cols = ['sex', 'cp', 'restecg', 'slope', 'thal']

# %%
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
# Identify one-hot encoded columns 
one_hot_cols = [col for col in df_encoded.columns if any(prefix + '_' in col for prefix in categorical_cols)]

# Convert only one-hot encoded columns to int
df_encoded[one_hot_cols] = df_encoded[one_hot_cols].astype(int)

# %%
df_encoded['fbs'] = df_encoded['fbs'].astype(int)
df_encoded['exang'] = df_encoded['exang'].astype(int)

# %%
df_encoded.head(3)
# Out:
#    age  trestbps   chol  fbs  thalch  exang  oldpeak   ca  sex_Male  \
# 0   63     145.0  233.0    1   150.0      0      2.3  0.0         1
# 1   67     160.0  286.0    0   108.0      1      1.5  3.0         1
# 2   67     120.0  229.0    0   129.0      1      2.6  2.0         1
#
#    cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 0                   0               0                  1               0
# 1                   0               0                  0               0
# 2                   0               0                  0               0
#
#    restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# 0                         0           0                0            0
# 1                         0           1                0            1
# 2                         0           1                0            0
#
#    thal_reversable defect
# 0                       0
# 1                       0
# 2                       1

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       920 non-null    int64
#  1   trestbps                  920 non-null    float64
#  2   chol                      920 non-null    float64
#  3   fbs                       920 non-null    int64
#  4   thalch                    920 non-null    float64
#  5   exang                     920 non-null    int64
#  6   oldpeak                   920 non-null    float64
#  7   ca                        920 non-null    float64
#  8   sex_Male                  920 non-null    int64
#  9   cp_atypical angina        920 non-null    int64
#  10  cp_non-anginal            920 non-null    int64
#  11  cp_typical angina         920 non-null    int64
#  12  restecg_normal            920 non-null    int64
# ...

# %% [markdown]
# # Applying Feature Scaling:

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_encoded)

# %%
# BEFORE SCALING
print("Ranges BEFORE Scaling:\n")
for col in df_encoded.columns:
    col_min = df_encoded[col].min()
    col_max = df_encoded[col].max()
    print(f"{col:30s} | min: {col_min:7.2f}, max: {col_max:7.2f}")
# Out:
# Ranges BEFORE Scaling:
#
# age                            | min:   28.00, max:   77.00
# trestbps                       | min:    0.00, max:  200.00
# chol                           | min:    0.00, max:  603.00
# fbs                            | min:    0.00, max:    1.00
# thalch                         | min:   60.00, max:  202.00
# exang                          | min:    0.00, max:    1.00
# oldpeak                        | min:   -2.60, max:    6.20
# ca                             | min:    0.00, max:    3.00
# sex_Male                       | min:    0.00, max:    1.00
# cp_atypical angina             | min:    0.00, max:    1.00
# cp_non-anginal                 | min:    0.00, max:    1.00
# cp_typical angina              | min:    0.00, max:    1.00
# restecg_normal                 | min:    0.00, max:    1.00
# restecg_st-t abnormality       | min:    0.00, max:    1.00
# slope_flat                     | min:    0.00, max:    1.00
# ...

# %%
scaled_df = pd.DataFrame(scaled_data, columns=df_encoded.columns)

# AFTER SCALING
print("\nRanges AFTER Scaling:\n")
for col in scaled_df.columns:
    col_min = scaled_df[col].min()
    col_max = scaled_df[col].max()
    print(f"{col:30s} | min: {col_min:7.2f}, max: {col_max:7.2f}")
# Out:
# Ranges AFTER Scaling:
#
# age                            | min:   -2.71, max:    2.49
# trestbps                       | min:   -7.16, max:    3.69
# chol                           | min:   -1.83, max:    3.70
# fbs                            | min:   -0.42, max:    2.38
# thalch                         | min:   -3.09, max:    2.56
# exang                          | min:   -0.76, max:    1.32
# oldpeak                        | min:   -3.27, max:    5.06
# ca                             | min:   -0.36, max:    4.41
# sex_Male                       | min:   -1.93, max:    0.52
# cp_atypical angina             | min:   -0.48, max:    2.07
# cp_non-anginal                 | min:   -0.53, max:    1.87
# cp_typical angina              | min:   -0.23, max:    4.36
# restecg_normal                 | min:   -1.23, max:    0.81
# restecg_st-t abnormality       | min:   -0.49, max:    2.03
# slope_flat                     | min:   -1.57, max:    0.64
# ...

# %% [markdown]
# # Model Training:

# %% [markdown]
# # Elbow method to choose optimal number of Clusters:

# %%
from sklearn.cluster import KMeans

inertia = []
k_range = range(1, 11)

for k in k_range:
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(scaled_data)
    inertia.append(model.inertia_)

plt.figure(figsize=(8,5))
plt.plot(k_range, inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (Within-Cluster Sum of Squares)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Applying K-means with 3 clusters:

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
cluster_labels = kmeans.fit_predict(scaled_data)

df_encoded['risk_cluster'] = cluster_labels

# %%
df_encoded.head()
# Out:
#    age  trestbps   chol  fbs  thalch  exang  oldpeak   ca  sex_Male  \
# 0   63     145.0  233.0    1   150.0      0      2.3  0.0         1
# 1   67     160.0  286.0    0   108.0      1      1.5  3.0         1
# 2   67     120.0  229.0    0   129.0      1      2.6  2.0         1
# 3   37     130.0  250.0    0   187.0      0      3.5  0.0         1
# 4   41     130.0  204.0    0   172.0      0      1.4  0.0         0
#
#    cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 0                   0               0                  1               0
# 1                   0               0                  0               0
# 2                   0               0                  0               0
# 3                   0               1                  0               1
# 4                   1               0                  0               0
#
#    restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# ...

# %% [markdown]
# # Analyzing Each Cluster:

# %%
cluster_profile = df_encoded.groupby('risk_cluster').mean().round(2)
print(cluster_profile)
# Out:
#                 age  trestbps    chol   fbs  thalch  exang  oldpeak    ca  \
# risk_cluster
# 0             49.08    127.90  215.06  0.06  142.10   0.15     0.39  0.02
# 1             58.29    137.76  183.55  0.26  123.76   0.67     1.43  0.35
# 2             52.69    128.80  202.70  0.12  155.20   0.20     0.63  0.36
#
#               sex_Male  cp_atypical angina  cp_non-anginal  cp_typical angina  \
# risk_cluster
# 0                 0.71                0.33            0.23               0.04
# 1                 0.91                0.03            0.16               0.06
# 2                 0.70                0.22            0.32               0.06
#
#               restecg_normal  restecg_st-t abnormality  slope_flat  \
# risk_cluster
# 0                       0.76                      0.14        0.98
# 1                       0.45                      0.31        0.84
# 2                       0.59                      0.09        0.00
#
# ...

# %% [markdown]
# # Mapping the Risk Labels:

# %%
risk_map = {
    0: 'Low Risk',
    1: 'High Risk',
    2: 'Medium Risk'
}

df_encoded['risk_label'] = df_encoded['risk_cluster'].map(risk_map)

# %% [markdown]
# # PCA Based Cluster Visualization:

# %%
from sklearn.decomposition import PCA

# Reduce to 2 dimensions with PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

# Add PCA components and cluster labels to a new DataFrame
viz_df = pd.DataFrame(pca_data, columns=['PCA1', 'PCA2'])
viz_df['Cluster'] = df_encoded['risk_label']

# Plot the clusters
plt.figure(figsize=(10, 7))
sns.scatterplot(data=viz_df, x='PCA1', y='PCA2', hue='Cluster', palette='Set1', s=80, edgecolor='black')

plt.title('K-Means Clusters of Heart Disease Patients (PCA-Reduced)', fontsize=14)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Risk Level')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # PairPlots:

# %%
selected_features = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca', 'risk_label']

# %%
# Create a DataFrame with selected features and labels
pairplot_df = df_encoded[selected_features].copy()

# Plot
sns.pairplot(pairplot_df, hue='risk_label', palette='Set1', corner=True, diag_kind='kde', plot_kws={'alpha': 0.6})
plt.suptitle('Pairplot of Key Features by Risk Level', y=1.02)
plt.show()

# %% [markdown]
# # One Random Patient per Risk Level:

# %%
random_seed = 42

for label in ['Low Risk', 'Medium Risk', 'High Risk']:
    print(f"\n--- {label} Example ---")
    patient = df_encoded[df_encoded['risk_label'] == label].sample(1, random_state=random_seed)
    display(patient)
# Out:
# --- Low Risk Example ---
#      age  trestbps   chol  fbs  thalch  exang  oldpeak   ca  sex_Male  \
# 512   49     160.0  180.0    0   156.0      0      1.0  0.0         0
#
#      cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 512                   0               1                  0               1
#
#      restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# 512                         0           1                0            1
#
#      thal_reversable defect  risk_cluster risk_label
# 512                       0             0   Low Risk
# --- Medium Risk Example ---
#      age  trestbps   chol  fbs  thalch  exang  oldpeak   ca  sex_Male  \
# 198   50     120.0  244.0    0   162.0      0      1.1  0.0         0
#
#      cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 198                   1               0                  0               1
#
# ...
